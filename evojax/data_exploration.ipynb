# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/results/results_run_0918_2018.csv", index_col=(0, 1, 2), header=0)

# %%
df.head()
# Out:
#                               0         1         2         3         4  \
# baseline train      0  0.663702  0.760328  0.787568  0.805751  0.817967
#          validation 0  0.741855  0.775590  0.790749  0.805376  0.810769
#          test       0  0.690457  0.729899  0.743300  0.758219  0.768229
#          train      1  0.651514  0.769089  0.797388  0.812031  0.824088
#          validation 1  0.748580  0.785778  0.799272  0.808283  0.815874
#
#                               5         6         7         8         9  \
# baseline train      0  0.826761  0.834601  0.840373  0.845981  0.849980
#          validation 0  0.818160  0.823042  0.826083  0.823708  0.831166
#          test       0  0.776340  0.778158  0.782199  0.783257  0.793077
#          train      1  0.831802  0.838196  0.843335  0.849036  0.853248
#          validation 1  0.823908  0.823753  0.827437  0.825284  0.827304
#
#                              10        11        12        13        14  \
# baseline train      0  0.855251  0.858557  0.861814  0.865611  0.868421
#          validation 0  0.832520  0.830455  0.830899  0.831321  0.832675
#          test       0  0.792318  0.790446  0.789117  0.792698  0.794434
#          train      1  0.858186  0.861645  0.864912  0.867477  0.871497
#          validation 1  0.829901  0.829324  0.833296  0.831410  0.835005
#
#                              15        16        17        18        19
# baseline train      0  0.870974  0.873358  0.877144  0.877924  0.881727
#          validation 0  0.834939  0.835871  0.834761  0.832209  0.836426
#          test       0  0.794651  0.796604  0.795085  0.791043  0.797553
#          train      1  0.874269  0.875322  0.878934  0.880128  0.883478
#          validation 1  0.826616  0.835693  0.833829  0.834961  0.835161

# %%
all_vals = df.loc[pd.IndexSlice[:, 'validation', :], :]
mean_val_acc = all_vals.groupby(level=0).mean()

# %%
epochs = mean_val_acc.columns
plt.plot(epochs, mean_val_acc.loc['baseline'], label='baseline')
plt.plot(epochs, mean_val_acc.loc['task_labels'], label='task_labels')
plt.plot(epochs, mean_val_acc.loc['dropout'], label='dropout')
plt.plot(epochs, mean_val_acc.loc['l1_reg'], label='l1_reg')
plt.title('Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
all_tests = df.loc[pd.IndexSlice[:, 'test', :], :]
mean_test_acc = all_tests.groupby(level=0).mean()
mean_test_acc
# Out:
#                     0         1         2         3         4         5  \
# baseline     0.695193  0.734163  0.752745  0.764377  0.771696  0.778434
# dropout      0.688260  0.727734  0.746674  0.759532  0.768506  0.774208
# l1_reg       0.695177  0.734104  0.753065  0.764480  0.772027  0.778738
# task_labels  0.696018  0.732633  0.752496  0.766016  0.772097  0.778792
#
#                     6         7         8         9        10        11  \
# baseline     0.782324  0.784549  0.786252  0.789529  0.790853  0.790896
# dropout      0.779639  0.783881  0.785417  0.788156  0.791168  0.793495
# l1_reg       0.782194  0.784809  0.786339  0.789659  0.790620  0.791075
# task_labels  0.782742  0.785981  0.787533  0.790576  0.792594  0.792839
#
#                    12        13        14        15        16        17  \
# baseline     0.791954  0.792150  0.793408  0.792247  0.794374  0.794341
# dropout      0.793636  0.796159  0.796175  0.797738  0.799208  0.800716
# l1_reg       0.791428  0.792448  0.793593  0.792307  0.794846  0.794352
# task_labels  0.792833  0.794672  0.794678  0.793495  0.795616  0.795817
#
#                    18        19
# baseline     0.792887  0.793159
# dropout      0.800537  0.801899
# l1_reg       0.792540  0.792882
# task_labels  0.794840  0.793533

# %%
epochs = mean_test_acc.columns
plt.plot(epochs, mean_test_acc.loc['baseline'], label='baseline')
plt.plot(epochs, mean_test_acc.loc['task_labels'], label='task_labels')
plt.plot(epochs, mean_test_acc.loc['dropout'], label='dropout')
plt.plot(epochs, mean_test_acc.loc['l1_reg'], label='l1_reg')
plt.title('Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df = pd.read_csv("./data/results/results_run_0919_1448.csv", index_col=(0, 1, 2), header=0)

# %%
all_tests = df.loc[pd.IndexSlice[:, 'test', :], :]
mean_test_acc = all_tests.groupby(level=0).mean()
mean_test_acc
# Out:
#                              0         1         2         3         4  \
# baseline              0.691578  0.733986  0.751302  0.763057  0.771385
# dropout               0.684986  0.726969  0.745660  0.758518  0.768717
# masking               0.691578  0.733986  0.751302  0.755434  0.764920
# masking_with_dropout  0.684986  0.726969  0.745660  0.750036  0.760887
#
#                              5         6         7         8         9  ...  \
# baseline              0.777181  0.782570  0.785925  0.786422  0.790066  ...
# dropout               0.773338  0.780093  0.784008  0.785500  0.788077  ...
# masking               0.770345  0.776792  0.778293  0.782100  0.785979  ...
# masking_with_dropout  0.766484  0.770182  0.776024  0.777986  0.780382  ...
#
#                             17        18        19        20        21  \
# baseline              0.795546  0.793547  0.794072       NaN       NaN
# dropout               0.799696  0.800383  0.801966       NaN       NaN
# masking               0.793719  0.794678  0.792987  0.794669  0.795202
# masking_with_dropout  0.791432  0.791567  0.792924  0.793050  0.793846
#
#                             22        23        24        25        26
# baseline                   NaN       NaN       NaN       NaN       NaN
# dropout                    NaN       NaN       NaN       NaN       NaN
# masking               0.792896  0.794452  0.795039  0.793367  0.794298
# masking_with_dropout  0.795437  0.795446  0.795889  0.796206  0.796278
#
# [4 rows x 27 columns]

# %%
epochs = mean_test_acc.columns
plt.plot(epochs, mean_test_acc.loc['baseline'], label='baseline')
plt.plot(epochs, mean_test_acc.loc['dropout'], label='dropout')
plt.plot(epochs, mean_test_acc.loc['masking'], label='masking')
plt.plot(epochs, mean_test_acc.loc['masking_with_dropout'], label='masking_with_dropout')
plt.title('Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
df = pd.read_csv("./data/results/results_run_0919_1555.csv", index_col=(0, 1, 2), header=0)

# %%
all_tests = df.loc[pd.IndexSlice[:, 'test', :], :]
mean_test_acc = all_tests.groupby(level=0).mean()
mean_test_acc
# Out:
#                              0         1         2         3         4  \
# baseline              0.695193  0.734163  0.752745  0.764377  0.771696
# dropout               0.688260  0.727734  0.746674  0.759532  0.768506
# masking               0.695193  0.734163  0.752745  0.764377  0.771696
# masking_with_dropout  0.686095  0.726145  0.744873  0.757666  0.767171
#
#                              5         6         7         8         9  ...  \
# baseline              0.778434  0.782324  0.784549  0.786252  0.789529  ...
# dropout               0.774208  0.779639  0.783881  0.785417  0.788156  ...
# masking               0.773372  0.777007  0.779894  0.782107  0.785862  ...
# masking_with_dropout  0.765685  0.770725  0.774387  0.775602  0.778857  ...
#
#                             30        31        32        33        34  \
# baseline              0.789914  0.789041  0.788249  0.788086  0.787912
# dropout               0.809326  0.809739  0.809918  0.810069  0.811572
# masking               0.792947  0.791303  0.792253  0.790538  0.791325
# masking_with_dropout  0.802018  0.802159  0.803103  0.802344  0.803038
#
#                             35        36        37        38        39
# baseline              0.788889  0.786518  0.786551  0.785357  0.786664
# dropout               0.811800  0.813156  0.813037  0.812782  0.812858
# masking               0.791900  0.789789  0.790489  0.789062  0.789453
# masking_with_dropout  0.803640  0.804552  0.805425  0.804183  0.804921
#
# [4 rows x 40 columns]

# %%
epochs = mean_test_acc.columns
plt.plot(epochs, mean_test_acc.loc['baseline'], label='baseline')
plt.plot(epochs, mean_test_acc.loc['dropout'], label='dropout')
plt.plot(epochs, mean_test_acc.loc['masking'], label='masking')
plt.plot(epochs, mean_test_acc.loc['masking_with_dropout'], label='masking_with_dropout')
plt.title('Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
